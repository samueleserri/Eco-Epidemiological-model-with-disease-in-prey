# %%
from DiscreteTimeModel import DiscreteTimeModel

# %% [markdown]
# Example 1:
#
# b = 0.2,
# c = 0.6,
# d = 0.12,
# k  = 0.1,
# m  = 0.2,
# \beta = 0.05,
# K = 8,
# $r \in [0.01, 4]$.
#
# With initial conditions:
# S0 = 4, I0 = 0.5, Y0 = 0.1

# %%
# instantiate the model
parameters = {
    "r": 0.001,
    "b":  0.2,
    "c": 0.6,
    "d": 0.12,
    "k": 0.1,
    "m": 0.2,
    "beta": 0.05,
    "K" : 8
}

initial_conditions = {
    "S0": 4,
    "I0": 0.5,
    "Y0": 0.1
}

model = DiscreteTimeModel(parameters)

# %% [markdown]
# $\mathcal{R}_0 = {K \beta}/{c}$

# %%
print("Basic Reproduction Number R0:", model.R0)
# Out:
# Basic Reproduction Number R0: 0.6666666666666667

# %%
model.r = 2
res = model.run(initial_conditions)
model.print_parameters()
model.plot_phase_space(initial_conditions, res=res)
# Out:
# r: 2
# b: 0.2
# c: 0.6
# d: 0.12
# k: 0.1
# m: 0.2
# beta: 0.05
# K: 8

# %%
# susceptible population vs parameter 
# model.plot_populations_vs_parameter("r", 0.01, 4, initial_conditions)

# %%
model.plot_bifurcation("r", 0.01, 4, initial_conditions)

# %%
parameters = {
    "r" : 0.01,
    "b": 0.15,
    "c": 0.1,
    "d": 0.2,
    "k": 0.2,
    "m": 0.3,
    "beta": 0.05,
    "K" : 4
}

initial_conditions = {
    "S0": 2,
    "I0": 1,
    "Y0": 0.5
}

model.update_parameters(parameters)

# %%
model.plot_bifurcation("r", 0.01, 7, initial_conditions)

# %%
model.r = 6.05
model.print_parameters()
model.plot_phase_space(initial_conditions)
# Out:
# r: 6.05
# b: 0.15
# c: 0.1
# d: 0.2
# k: 0.2
# m: 0.3
# beta: 0.05
# K: 4

# %%
parameters = {
    "r" : 0.1,
    "b": 0.1,
    "c": 0.6,
    "d": 0.6,
    "k": 0.1,
    "m": 0.5,
    "beta": 0.1,
    "K" : 10
}

initial_conditions = {
    "S0": 6,
    "I0": 2,
    "Y0": 1
}

model.update_parameters(parameters)

# %%
model.plot_bifurcation("c", 0.01, 2.5, initial_conditions)
# Out:
# /home/sam/Documents/uni/III ANNO/UniTS/Teoria dell'informazione e sistemi dinamici/complex systems/project/Eco-Epidemiological-model-with-disease-in-prey/src/DiscreteTimeModel.py:229: RuntimeWarning: invalid value encountered in scalar divide
#   return I * np.exp(self.beta * S - self.c - (self.b * Y) / (self.m * Y + I))
# /home/sam/Documents/uni/III ANNO/UniTS/Teoria dell'informazione e sistemi dinamici/complex systems/project/Eco-Epidemiological-model-with-disease-in-prey/src/DiscreteTimeModel.py:232: RuntimeWarning: invalid value encountered in scalar divide
#   return Y * np.exp((self.k * self.b * I) / (self.m * Y + I) - self.d)

# %%
parameters = {
    "r" : 3,
    "b": 0.2,
    "c": 0.6,
    "d": 0.2,
    "k": 0.2,
    "m": 0.5,
    "beta": 0.2,
    "K" : 10
}

initial_conditions = {
    "S0": 6,
    "I0": 2,
    "Y0": 1
}

model.update_parameters(parameters)

# %%
model.plot_bifurcation("c", 0.5, 2.5, initial_conditions)

# %%
model.c = 3/2
model.print_parameters()
model.plot_phase_space(initial_conditions)
# Out:
# r: 3
# b: 0.2
# c: 1.5
# d: 0.2
# k: 0.2
# m: 0.5
# beta: 0.2
# K: 10

# %%
parameters = {
    "r" : 0.2,
    "b": 0.1,
    "c": 0.4,
    "d": 0.2,
    "k": 0.2,
    "m": 0.5,
    "beta": 0.2,
    "K" : 10
}

initial_conditions = {
    "S0": 1,
    "I0": 0.5,
    "Y0": 2
}

model.update_parameters(parameters)

# %%
model.plot_bifurcation("K", 2, 8, initial_conditions)

# %%
model.K = 4
model.print_parameters()
model.plot_phase_space(initial_conditions)
# Out:
# r: 0.2
# b: 0.1
# c: 0.4
# d: 0.2
# k: 0.2
# m: 0.5
# beta: 0.2
# K: 4

# %%
parameters = {
    "r" : 4,
    "b": 0.15,
    "c": 0.5,
    "d": 0.2,
    "k": 0.2,
    "m": 0.3,
    "beta": 0.1,
    "K" : 4
}

initial_conditions = {
    "S0": 2,
    "I0": 1,
    "Y0": 1
}

model.update_parameters(parameters)

# %%
model.plot_bifurcation("beta", 0.125, 0.42, initial_conditions)

# %%
model.plot_phase_space(initial_conditions)

# %%
# endemic equilibrium simulation
parameters = {
    "r" : 1.2,
    "b": 0.28,
    "c": 0.1,
    "d": 0.02,
    "k": 0.3,
    "m": 0.4,
    "beta": 0.25,
    "K" : 6
}

initial_conditions = {
    "S0": 2,
    "I0": 1.5,
    "Y0": 1
}

model.update_parameters(parameters)

# %%
model.plot_bifurcation("b", 0.15, 0.7, initial_conditions)

# %%
model.b  = 0.2
model.print_parameters()
model.plot_phase_space(initial_conditions)
# Out:
# r: 1.2
# b: 0.2
# c: 0.1
# d: 0.02
# k: 0.3
# m: 0.4
# beta: 0.25
# K: 6

# %%
# amplification
model.plot_bifurcation("b", 0.5, 0.6, initial_conditions, population='S')

# %%
parameters = {
    "r" : 1.2,
    "b": 0.3,
    "c": 0.1,
    "d": 0.04,
    "k": 0.34,
    "m": 0.3,
    "beta": 0.25,
    "K" : 6
}

initial_conditions = {
    "S0": 2,
    "I0": 1.5,
    "Y0": 1
}

model.update_parameters(parameters)

# %%
model.plot_bifurcation("k", 0.1, 1, init=initial_conditions)

# %%
model.print_parameters()
model.plot_phase_space(initial_conditions)
# Out:
# r: 1.2
# b: 0.3
# c: 0.1
# d: 0.04
# k: 1
# m: 0.3
# beta: 0.25
# K: 6
